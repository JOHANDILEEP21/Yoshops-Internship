# %% [markdown]
# # Project Task-1
#
# ## Write a python program to displayed products count number by products main categories and sub categories.
#
# ## Enter 1 put value link = Yoshops.com
#
# ##Enter 2 put categories link=
#
# ###Output = create excel file with Name Category, Products count,Total products count.
#
# ###After completing task please convert your PY file to EXE file and uploaded both py file and Exe file in mega.io and send link to me WhatsApp

# %%
import pandas as pd
import numpy as np
import urllib.request
from urllib import request
from bs4 import BeautifulSoup
import requests as r
import requests

# %%
# This function finds entire categories count of products 
def product_count():
  baseurl='https://' 
  cat_links = []
  cat_names = []
  pl = []
  b = []
  cat = []

  value_link =input('Enter value Link= ')
  #value_link = input('Enter the URL: ')
  print(value_link)

  for x in range(1):
    r = urllib.request.urlopen(baseurl+value_link).read()
    soup = BeautifulSoup(r, 'lxml')
    cat_list = soup.find('ul', class_='nav category-bar').find_all('li', class_='dropdown')
    for cat in cat_list:
      for link in cat.find_all('a', class_=False, href=True, span=False):
        cat_links.append(baseurl+value_link+link['href'])
        cat_names.append(link.text)  
      
  # Create a DataFrame with some data
  data = {'Category Links': cat_links,'Category Names':cat_names}
  df = pd.DataFrame(data)
  df
  
  sub_cat_links = []
  sub_cat_names = []
  sub_pl = []
  sub_b = []

  for x in range(1):
    
    r = urllib.request.urlopen(baseurl+value_link).read()
    soup = BeautifulSoup(r, 'lxml')
    sub_cat_list = soup.find('ul', class_='nav category-bar').find_all('ul', class_='dropdown-menu')
    for cat in sub_cat_list:
      for link in cat.find_all('a', class_=False, href=True, span=False):
        sub_cat_links.append(baseurl+value_link+link['href'])
        sub_cat_names.append(link.text)

  main_cat_links = []
  main_cat_names = []
  main_pl = []
  main_b = []

  for x in range(len(cat_links)):
    if (cat_links[x] in sub_cat_links):
      pass
    else:
      main_cat_links.append(cat_links[x])
      main_cat_names.append(cat_names[x])
  print(main_cat_links, '\n', len(main_cat_links),'\n', main_cat_names, '\n', len(main_cat_names))
  print(sub_cat_links,'\n', len(sub_cat_links),'\n', sub_cat_names,'\n',len(sub_cat_names))

  cat = [main_cat_links, sub_cat_links, main_cat_names, sub_cat_names]
  pl1 = []
  pl2 = []
  b1 = []
  b2 = []

  for j in range(len(cat)-1):
    if j == 0:
      print('Main Categories')
      for k in range(len(cat[j])):
        tgttls = []
        tglks = []
        #pl1.append(main_cat_links[k])
        pl1.append(cat[j+2][k])
        print('Working with Main categories Link: ', cat[j][k])
        r = urllib.request.urlopen(cat[j][k]).read()
        soup = BeautifulSoup(r, 'lxml')
        a = soup.find('ul', class_='pagination pull-right')#.find_all('ul',class_='num')
        if (str(a) == 'None'):
          #print(type(a))
          r = urllib.request.urlopen(cat[j][k]).read()
          soup = BeautifulSoup(r,'lxml')
          url = cat[j][k]
          headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/89.0.4389.82 Safari/537.36'}
          req = requests.get(url, headers = headers).text
          soup = BeautifulSoup(req, 'html.parser')
          
          tgttl = soup.find_all('span', class_='product-title')
          for i in range(len(tgttl)):
            tgttls.append(tgttl[i].text)
          
          df_cnt = len(tgttls)
          print('Product Count: ', df_cnt)

          b1.append(df_cnt)
        else:
          for x in range(1):
            r = urllib.request.urlopen(cat[j][k]).read()
            soup = BeautifulSoup(r, 'lxml')
            page_num = soup.find('ul', class_='pagination pull-right').find_all('li',class_='num')

            pages = list(range(1, len(page_num)+1))
            for page in pages:
              url = cat[j][k]+'?page={}'
              headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/89.0.4389.82 Safari/537.36'}
              req = requests.get(url.format(page), headers = headers).text
              soup = BeautifulSoup(req, 'html.parser')
              
              tgttl = soup.find_all('span', class_='product-title')
              for i in range(len(tgttl)):
                  tgttls.append(tgttl[i].text)
          
          df_cnt = len(tgttls)
          print('Product Count: ',df_cnt)

          b1.append(df_cnt)
      # Create a DataFrame with some data
      main_data = {'Main Category': pl1,'Total Product Count':b1}
      main_df = pd.DataFrame(main_data)
    elif j ==1:
      print('Sub Categories')
      for k in range(len(cat[j])):
        tgttls = []
        tglks = []
        #pl1.append(main_cat_links[k])
        pl2.append(cat[j+2][k])
        print('Working with Sub categories Link: ', cat[j][k])
        r = urllib.request.urlopen(cat[j][k]).read()
        soup = BeautifulSoup(r, 'lxml')
        a = soup.find('ul', class_='pagination pull-right')#.find_all('ul',class_='num')
        if (str(a) == 'None'):
          #print(type(a))
          r = urllib.request.urlopen(cat[j][k]).read()
          soup = BeautifulSoup(r,'lxml')
          url = cat[j][k]
          headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/89.0.4389.82 Safari/537.36'}
          req = requests.get(url, headers = headers).text
          soup = BeautifulSoup(req, 'html.parser')
          
          tgttl = soup.find_all('span', class_='product-title')
          for i in range(len(tgttl)):
            tgttls.append(tgttl[i].text)
          
          df_cnt = len(tgttls)
          print('Product Count: ', df_cnt)

          b2.append(df_cnt)
        else:
          for x in range(1):
            r = urllib.request.urlopen(cat[j][k]).read()
            soup = BeautifulSoup(r, 'lxml')
            page_num = soup.find('ul', class_='pagination pull-right').find_all('li',class_='num')

            pages = list(range(1, len(page_num)+1))
            for page in pages:
              url = cat[j][k]+'?page={}'
              headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/89.0.4389.82 Safari/537.36'}
              req = requests.get(url.format(page), headers = headers).text
              soup = BeautifulSoup(req, 'html.parser')
              
              tgttl = soup.find_all('span', class_='product-title')
              for i in range(len(tgttl)):
                  tgttls.append(tgttl[i].text)
          
          df_cnt = len(tgttls)
          print('Product Count: ',df_cnt)

          b2.append(df_cnt)
      # Create a DataFrame with some data
      sub_data = {'Sub Category': pl2,'Total Product Count':b2}
      sub_df = pd.DataFrame(sub_data)

  with pd.ExcelWriter('/content/drive/MyDrive/YoShops Internship/Project Task 1/Task1.xlsx') as writer:
    main_df.to_excel(writer, sheet_name='Main Categories', index=False)
    sub_df.to_excel(writer, sheet_name='Sub Categories', index=False)

  print('\nMain Categorywise Product Count\n', main_df,'\n\nSub categorywise Product Count\n', sub_df)

# %%
# This function works to find the product counts of individual category
def main_file():
  baseurl='https://'
  b = []
  productlinks=[]
  tgttls = []
  tglks = []
  pdc = []
  page_n=[]
  pl = []



  while True:
    try:
      print('\n\nEnter 1 put value link = \nEnter 2 put categories link= \nEnter 3 to Display Products count number by products main categories: \n')
      n = int(input())
      b = []
      productlinks=[]
      tgttls = []
      tglks = []
      pdc = []
      page_n=[]
      pl = []
      if n ==1:
        global value_link
        value_link = input('Enter Value link= ')
        print(value_link)
        
        cat_links = []
        cat_names = []
        pl = []
        b = []
        cat = []

        for x in range(1):
          r = urllib.request.urlopen(baseurl+value_link).read()
          soup = BeautifulSoup(r, 'lxml')
          cat_list = soup.find('ul', class_='nav category-bar').find_all('li', class_='dropdown')
          for cat in cat_list:
            for link in cat.find_all('a', class_=False, href=True, span=False):
              cat_links.append(baseurl+value_link+link['href'])
              cat_names.append(link.text)  
            
        # Create a DataFrame with some data
        data = {'Category Links': cat_links,'Category Names':cat_names}
        df = pd.DataFrame(data)
        print(df)
        
      elif n ==2:
        b1 = []
        cate_link = input('Enter Categories link= ')
        print(cate_link)
        if cate_link in cat_links:
          r = urllib.request.urlopen(cate_link).read()
          soup = BeautifulSoup(r,'lxml')
          url = cate_link+'?page={}'
          headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/89.0.4389.82 Safari/537.36'}
          req = requests.get(url, headers = headers).text
          soup = BeautifulSoup(req, 'html.parser')
          a = soup.find('ul', class_='pagination pull-right')#.find_all('ul',class_='num')
          if (str(a) == 'None'):
            #print(type(a))
            r = urllib.request.urlopen(cate_link).read()
            soup = BeautifulSoup(r,'lxml')
            url = cate_link
            headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/89.0.4389.82 Safari/537.36'}
            req = requests.get(url, headers = headers).text
            soup = BeautifulSoup(req, 'html.parser')
            
            tgttl = soup.find_all('span', class_='product-title')
            for i in range(len(tgttl)):
              tgttls.append(tgttl[i].text)
            
            df_cnt = len(tgttls)
            print('Product Count: ', df_cnt)

            b1.append(df_cnt)
          else:
            for x in range(1):
              r = urllib.request.urlopen(cate_link).read()
              soup = BeautifulSoup(r, 'lxml')
              page_num = soup.find('ul', class_='pagination pull-right').find_all('li',class_='num')

              pages = list(range(1, len(page_num)+1))
              for page in pages:
                url = cate_link+'?page={}'
                headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/89.0.4389.82 Safari/537.36'}
                req = requests.get(url.format(page), headers = headers).text
                soup = BeautifulSoup(req, 'html.parser')
                
                tgttl = soup.find_all('span', class_='product-title')
                for i in range(len(tgttl)):
                    tgttls.append(tgttl[i].text)
            
            df_cnt = len(tgttls)
            print('Product Count: ',df_cnt)

            b1.append(df_cnt)
            
          cat_data = {'Category': cate_link,'Total Product Count':b1}
          cat_df = pd.DataFrame(cat_data)

          # Print the updated DataFrame
          print(cat_df)
          #df.to_excel('Web_Scrapping.xlsx', sheet_name='Yoshops Products', index=False)
        else:
          print('You were entered wrong category\nPlease Enter the category name correctly...:-)')
      elif n ==3:
        product_count()
              
      else:
        break
    except Exception as e:
      print(e)

# %%
mf = main_file()
mf
# Out:
# Enter 1 put value link =
# Enter 2 put categories link=
# Enter 3 to Display Products count number by products main categories:
#
# 1
# Enter Value link= yoshops.com
# yoshops.com
#                                        Category Links  \
# 0                          https://yoshops.com/t/toys
# 1                   https://yoshops.com/t/playstation
# 2                        https://yoshops.com/t/drones
# 3                 https://yoshops.com/t/rc-helicopter
# 4                     https://yoshops.com/t/soft-toys
# ..                                                ...
# 59         https://yoshops.com/t/youtuber-sponsorship
# 60  https://yoshops.com/t/refurbished-and-used-lap...
# 61                    https://yoshops.com/t/bengaluru
# 62                      https://yoshops.com/t/chennai
# 63                       https://yoshops.com/t/mumbai
#
#               Category Names
# 0              Toys & Games
# 1                PlayStation
# 2                     Drones
# ...

# %%
pd.read_excel('/content/drive/MyDrive/YoShops Internship/Project Task 1/Task1.xlsx', sheet_name='Main Categories')
# Out:
#      Main Category  Total Product Count
# 0    Toys & Games                    93
# 1         Mobiles                   165
# 2         Laptops                    67
# 3     Accessories                   109
# 4     Electronics                    29
# 5  Home & Kitchen                    31
# 6         Fashion                    72
# 7           Foods                    58
# 8        Services                   154

# %%
pd.read_excel('/content/drive/MyDrive/YoShops Internship/Project Task 1/Task1.xlsx', sheet_name='Sub Categories')
# Out:
#                           Sub Category  Total Product Count
# 0                          PlayStation                    7
# 1                               Drones                   19
# 2                              RC Toys                   13
# 3                            Soft Toys                   32
# 4                   Gaming Accessories                   52
# 5                          Smartphones                    5
# 6                           Headphones                   91
# 7                  Mobiles Accessories                   70
# 8               Feature Keypad Mobiles                    9
# 9                       Gaming Laptops                    5
# 10                    Personal Laptops                    5
# 11                             Tablets                    6
# 12                  Laptop Accessories                   59
# 13               Computers Accessories                   53
# 14                               Books                   10
# ...
